# %% [markdown]
# # Heart Desease

# %%
import pandas as pd

# %%
df = pd.read_csv("heart-disease.csv")
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
import matplotlib.pyplot as plt

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %% [markdown]
# ## Problem Defination
#
# Predict Heart disease

# %%
# !dir
# Out:
#  Volume in drive F has no label.
#  Volume Serial Number is AA07-F4E6
#
#  Directory of F:\Practice\ML\Sample Project 1
#
# 10/27/2025  09:16 PM    <DIR>          .
# 10/26/2025  10:08 PM    <DIR>          ..
# 10/27/2025  09:12 PM    <DIR>          .ipynb_checkpoints
# 10/27/2025  08:03 PM            11,328 heart-disease.csv
# 10/27/2025  09:16 PM            21,550 ML-01.ipynb
# 10/27/2025  09:08 PM            63,929 note of ML.png
#                3 File(s)         96,807 bytes
#                3 Dir(s)  238,217,388,032 bytes free

# %% [markdown]
# ## Data
#
# This is the data we are using
